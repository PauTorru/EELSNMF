# %%
# %load_ext autoreload
# %autoreload 2

# %%
sys.path

# %%
from EELSNMF.refactor import base,modelG

# %%
f = r"C:\Users\torruell\Documents\EPFL\eth robin\20240124 FeCr40_1008h_DM\SI data (9 - 32  velox)\EELS HL SI.dm4"
s = hs.load(f)

# %%
s = s.rebin(scale=[2,2,2])

# %%
a=tuple((1,2))
b=tuple((2,3))
a+b
# Out:
# (1, 2, 2, 3)

# %%
s.plot()
# Out:
# findfont: Font family ['cmsy10'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['cmr10'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['cmtt10'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['cmmi10'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['cmb10'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['cmss10'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['cmex10'] not found. Falling back to DejaVu Sans.

# %%
s.data = np.maximum(s.data,0)

# %%
deco = base.EELSNMF(s.isig[:-10])
deco.build_G(None,
             {"O_K":(525.,550.),"Cr_L":(569.,605.),"Fe_L":(702.,735.)},
            )
deco.decomposition(3,max_iters=300)
# Out:
# L2 is used
# L1 is used
# L2 is used
# L1 is used
# 100%|████████████████████████████████████████| 300/300 [01:23<00:00,  3.58it/s, error=6.46e+7, relative change=8.99e-5]

# %%
deco.plot_factors()
# Out:
# cupy not available

# %%
deco.plot_loadings()

# %%
deco.plot_average_model()
# Out:
# cupy not available
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[121], line 1
# ----> 1 deco.plot_average_model()
#
# File C:\\Users\\torruell\\Documents\\GitHub\EELSNMF\refactor\plot.py:72, in Plots.plot_average_model(self)
#      70 plt.clf()
#      71 plt.plot(self.energy_axis,self.X.mean(1),label="Data")
# ---> 72 plt.plot(self.energy_axis,self.get_model().mean(1),label="Model")
#      73 plt.legend()
#
# AttributeError: 'EELSNMF' object has no attribute 'get_model'

# %%
plt.plot(deco.model.G)
# Out:
# [<matplotlib.lines.Line2D at 0x26592fb90d0>,
#  <matplotlib.lines.Line2D at 0x26591dc7910>,
#  <matplotlib.lines.Line2D at 0x26591d8bdd0>,
#  <matplotlib.lines.Line2D at 0x26591d8a050>,
#  <matplotlib.lines.Line2D at 0x26592fc5110>,
#  <matplotlib.lines.Line2D at 0x26591d8f450>,
#  <matplotlib.lines.Line2D at 0x26591dd1290>,
#  <matplotlib.lines.Line2D at 0x26591d8edd0>,
#  <matplotlib.lines.Line2D at 0x26591d8e410>,
#  <matplotlib.lines.Line2D at 0x26591d8c1d0>,
#  <matplotlib.lines.Line2D at 0x26591d533d0>,
#  <matplotlib.lines.Line2D at 0x26592f05210>,
#  <matplotlib.lines.Line2D at 0x26591dfd6d0>,
#  <matplotlib.lines.Line2D at 0x26591dd0910>,
#  <matplotlib.lines.Line2D at 0x26591dffcd0>,
#  <matplotlib.lines.Line2D at 0x26592fb2910>,
#  <matplotlib.lines.Line2D at 0x26591dfddd0>,
#  <matplotlib.lines.Line2D at 0x26591dd1410>,
#  <matplotlib.lines.Line2D at 0x26591dfec10>,
#  <matplotlib.lines.Line2D at 0x26592f96310>,
#  <matplotlib.lines.Line2D at 0x26591dffa50>,
#  <matplotlib.lines.Line2D at 0x26591dfea10>,
#  <matplotlib.lines.Line2D at 0x26591dfdfd0>,
#  <matplotlib.lines.Line2D at 0x26591dfc690>,
#  <matplotlib.lines.Line2D at 0x265957d2150>,
#  <matplotlib.lines.Line2D at 0x26591dffd10>,
#  <matplotlib.lines.Line2D at 0x26592f94850>,
#  <matplotlib.lines.Line2D at 0x26591df6b50>,
#  <matplotlib.lines.Line2D at 0x26591df7050>,
#  <matplotlib.lines.Line2D at 0x26592fc08d0>,
#  <matplotlib.lines.Line2D at 0x26591df6790>,
#  <matplotlib.lines.Line2D at 0x26591df7a90>,
#  <matplotlib.lines.Line2D at 0x26591df58d0>,
#  <matplotlib.lines.Line2D at 0x265a0f781d0>,
#  <matplotlib.lines.Line2D at 0x26592f94f50>,
#  <matplotlib.lines.Line2D at 0x26591dd27d0>,
#  <matplotlib.lines.Line2D at 0x26591df4990>,
#  <matplotlib.lines.Line2D at 0x26591df4090>,
#  <matplotlib.lines.Line2D at 0x265957d3c90>,
#  <matplotlib.lines.Line2D at 0x26591df6c10>,
#  <matplotlib.lines.Line2D at 0x26591da8ad0>,
#  <matplotlib.lines.Line2D at 0x26591daaa90>,
#  <matplotlib.lines.Line2D at 0x26591da8090>,
#  <matplotlib.lines.Line2D at 0x26591da9290>,
#  <matplotlib.lines.Line2D at 0x26591daa790>,
#  <matplotlib.lines.Line2D at 0x26592f01c50>,
#  <matplotlib.lines.Line2D at 0x26592f03f50>,
#  <matplotlib.lines.Line2D at 0x26591e36510>,
#  <matplotlib.lines.Line2D at 0x26592fc77d0>,
#  <matplotlib.lines.Line2D at 0x26592f03250>,
#  <matplotlib.lines.Line2D at 0x26592f33890>,
#  <matplotlib.lines.Line2D at 0x26592fc47d0>,
#  <matplotlib.lines.Line2D at 0x26591dd2b10>,
#  <matplotlib.lines.Line2D at 0x26591d95110>,
#  <matplotlib.lines.Line2D at 0x26580e8ac90>,
#  <matplotlib.lines.Line2D at 0x26592f95750>,
#  <matplotlib.lines.Line2D at 0x26591d94b10>,
#  <matplotlib.lines.Line2D at 0x26591dd0710>,
#  <matplotlib.lines.Line2D at 0x26591dd02d0>,
#  <matplotlib.lines.Line2D at 0x26591e10c50>,
#  <matplotlib.lines.Line2D at 0x26591daa350>,
#  <matplotlib.lines.Line2D at 0x26591dc7cd0>,
#  <matplotlib.lines.Line2D at 0x26596376590>,
#  <matplotlib.lines.Line2D at 0x26591daa990>,
#  <matplotlib.lines.Line2D at 0x26591e13510>,
#  <matplotlib.lines.Line2D at 0x26591e13150>,
#  <matplotlib.lines.Line2D at 0x26591e10e90>,
#  <matplotlib.lines.Line2D at 0x26591e37d50>,
#  <matplotlib.lines.Line2D at 0x26591e12890>,
#  <matplotlib.lines.Line2D at 0x26596377350>,
#  <matplotlib.lines.Line2D at 0x26591dea150>,
#  <matplotlib.lines.Line2D at 0x26591e11a90>,
#  <matplotlib.lines.Line2D at 0x26591e35590>,
#  <matplotlib.lines.Line2D at 0x26591e35150>,
#  <matplotlib.lines.Line2D at 0x265a0f23590>,
#  <matplotlib.lines.Line2D at 0x26591e37890>,
#  <matplotlib.lines.Line2D at 0x26592fcddd0>,
#  <matplotlib.lines.Line2D at 0x265a0f22c50>,
#  <matplotlib.lines.Line2D at 0x2659087fbd0>,
#  <matplotlib.lines.Line2D at 0x2659060b350>,
#  <matplotlib.lines.Line2D at 0x26590608710>,
#  <matplotlib.lines.Line2D at 0x265908fe890>,
#  <matplotlib.lines.Line2D at 0x265905ef4d0>,
#  <matplotlib.lines.Line2D at 0x26592fbd850>,
#  <matplotlib.lines.Line2D at 0x26591d887d0>,
#  <matplotlib.lines.Line2D at 0x26590560450>,
#  <matplotlib.lines.Line2D at 0x265908def50>,
#  <matplotlib.lines.Line2D at 0x26592f313d0>,
#  <matplotlib.lines.Line2D at 0x26591d60810>,
#  <matplotlib.lines.Line2D at 0x26591e356d0>,
#  <matplotlib.lines.Line2D at 0x2659a639850>,
#  <matplotlib.lines.Line2D at 0x26591e34b50>,
#  <matplotlib.lines.Line2D at 0x26591e273d0>,
#  <matplotlib.lines.Line2D at 0x26599cdab50>,
#  <matplotlib.lines.Line2D at 0x26599cd8710>,
#  <matplotlib.lines.Line2D at 0x26599cdb850>,
#  <matplotlib.lines.Line2D at 0x26591df5dd0>,
#  <matplotlib.lines.Line2D at 0x26594fd9390>,
#  <matplotlib.lines.Line2D at 0x26594fd9850>,
#  <matplotlib.lines.Line2D at 0x26594fdbbd0>,
#  <matplotlib.lines.Line2D at 0x26590608890>,
#  <matplotlib.lines.Line2D at 0x26599fd7750>,
#  <matplotlib.lines.Line2D at 0x26591dd1010>,
#  <matplotlib.lines.Line2D at 0x26591dd0390>,
#  <matplotlib.lines.Line2D at 0x26591d95310>,
#  <matplotlib.lines.Line2D at 0x26599fd4f90>,
#  <matplotlib.lines.Line2D at 0x26591dd1e10>,
#  <matplotlib.lines.Line2D at 0x26599fd4690>,
#  <matplotlib.lines.Line2D at 0x26599fd4090>,
#  <matplotlib.lines.Line2D at 0x265975e3e50>,
#  <matplotlib.lines.Line2D at 0x26599cdb010>,
#  <matplotlib.lines.Line2D at 0x26591e37050>,
#  <matplotlib.lines.Line2D at 0x265975e1410>,
#  <matplotlib.lines.Line2D at 0x26592fbd990>,
#  <matplotlib.lines.Line2D at 0x265975e0590>,
#  <matplotlib.lines.Line2D at 0x26592fc4d10>,
#  <matplotlib.lines.Line2D at 0x265975e29d0>,
#  <matplotlib.lines.Line2D at 0x265975e3f10>,
#  <matplotlib.lines.Line2D at 0x26591e36b10>,
#  <matplotlib.lines.Line2D at 0x26596359350>,
#  <matplotlib.lines.Line2D at 0x265975e35d0>,
#  <matplotlib.lines.Line2D at 0x26591dc7f90>,
#  <matplotlib.lines.Line2D at 0x2659635b010>,
#  <matplotlib.lines.Line2D at 0x26599fa2d90>,
#  <matplotlib.lines.Line2D at 0x265975e1910>,
#  <matplotlib.lines.Line2D at 0x26591e375d0>,
#  <matplotlib.lines.Line2D at 0x26599fa1b50>,
#  <matplotlib.lines.Line2D at 0x26599fa0250>,
#  <matplotlib.lines.Line2D at 0x26599fa3390>,
#  <matplotlib.lines.Line2D at 0x2659635b5d0>,
#  <matplotlib.lines.Line2D at 0x26599fa2a10>,
#  <matplotlib.lines.Line2D at 0x265975e2450>,
#  <matplotlib.lines.Line2D at 0x26599fa1750>,
#  <matplotlib.lines.Line2D at 0x26599fa1810>,
#  <matplotlib.lines.Line2D at 0x26599fa02d0>,
#  <matplotlib.lines.Line2D at 0x265975e2cd0>,
#  <matplotlib.lines.Line2D at 0x26591e138d0>]

# %%
deco.energy_axis.shape
# Out:
# (422,)

# %%
a=[5,100,100,150]
np.cumsum(a)
# Out:
# array([  5, 105, 205, 355])

# %%
X = np.random.random((3000,10000))
G = np.random.random((3000,800))
W = np.random.random((800,5))
H = np.random.random((5,10000))

import time 
t0 = time.time()
for i in range(20):

    p = abs(X-G@W@H).sum()


t1 = time.time()
for i in range(20):

    p = abs(X-np.einsum("ij,jk,kp->ip",G,W,H,optimize="greedy")).sum()

t2=time.time()

# %%
print(t1-t0)
print(t2-t1)
# Out:
# 9.71052622795105
# 10.69381070137024

# %%
i
# Out:
# 3

# %%
class Methods():
    def __init__(self):
        self.a="a"
    def op1(self,x,y):
        return x+y
    def op2(self,x):
        self.x2=x*x
        return self.x2

class Other():
    def __init__(self):
        self.b="b"
        self.a="ba"
    def printx2(self):
        print(self.x2)
    def say_hi(self):
        print("hi")


class All(Methods,Other):
    pass

# %%
a=np.ones((3,5))
b=np.ones((3,2))*2

np.concatenate([a,b],axis=1)

# %%
a = All()

# %%
a.op2(2)

# %%
eaxis_parameters = {
		"offset":10,
		"scale":0.1,
		"name":"chuchu",
		"units":"mm",
    "axis":np.linspace(0,10-0.1,100)+10
		}

# %%
eaxis_parameters["axis"]

# %%
ax = a.axes_manager[-1]

# %%
a.plot()

# %%
import pickle as pkl
import dill

# %%
with open("pf.pkl","wb") as f:
    dill.dump(a,f)

# %%
a.x2=np.array([1])
b = getattr(a,"x2")
b=b.astype("float")
a.x2.dtype

# %%
a.printx2()

# %%
a.say_hi()

# %%
a.op1(1,2)

# %%
hasattr(a,"op1")

# %%
getattr(a,"x2")

# %%
print(1)
raise Exception("what")
1+1
